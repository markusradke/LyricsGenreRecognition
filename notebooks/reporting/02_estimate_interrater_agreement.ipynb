# %%
import pickle

# %%
cat5_mc = pickle.load("../../models/interrater_agreement/ira_cat5.pkl")
print(cat5_mc)
# Out:
# Simulated Interrater Agreement:
# ...
# Number of MC runs: 10
# Overall Macro F1: 0.789 (sd: 0.001, CI: 0.788-0.790)
# ...
# Per-Genre F1:
# genre
# electronic    0.727502
# hiphop        0.904045
# metal         0.712975
# pop           0.767515
# rock          0.835377

# %%
cat12_mc = pickle.load("../../models/interrater_agreement/ira_cat5.pkl")
print(cat12_mc)
# Out:
# Simulated Interrater Agreement:
# ...
# Number of MC runs: 10
# Overall Macro F1: 0.602 (sd: 0.001, CI: 0.601-0.603)
# ...
# Per-Genre F1:
# genre
# alternativerock    0.386923
# electronic         0.727251
# hardrock           0.376157
# heavymetal         0.548348
# hiphop             0.904099
# indierock          0.412769
# jazz               0.709772
# metal              0.713369
# pop                0.703017
# poprock            0.272290
# rock               0.677160
# schlager           0.796219

# %%
cat25_mc = pickle.load("../../models/interrater_agreement/ira_cat5.pkl")
print(cat25_mc)
# Out:
# Simulated Interrater Agreement:
# ...
# Number of MC runs: 10
# Overall Macro F1: 0.480 (sd: 0.002, CI: 0.478-0.483)
# ...
# Per-Genre F1:
# genre
# alternativerock     0.386923
# bluesrock           0.340918
# classical           0.783126
# classicrock         0.221247
# deathmetal          0.489440
# electronic          0.727042
# folk                0.422901
# folkrock            0.330796
# hardrock            0.374301
# heavymetal          0.404299
# hiphop              0.904124
# indierock           0.412780
# jazz                0.709879
# metal               0.642872
# pop                 0.620275
# poprock             0.273399
# powermetal          0.474597
# progressiverock     0.466295
# punk                0.470020
# rb                  0.291852
# rock                0.526911
# schlager            0.796129
# singersongwriter    0.260673
# soul                0.394272
# synthpop            0.273801

# %%
cat32_mc = pickle.load("../../models/interrater_agreement/ira_cat5.pkl")
print(cat32_mc)
# Out:
# Simulated Interrater Agreement:
# ...
# Number of MC runs: 10
# Overall Macro F1: 0.463 (sd: 0.002, CI: 0.461-0.466)
# ...
# Per-Genre F1:
# genre
# alternativerock     0.386923
# blues               0.450896
# bluesrock           0.342217
# classical           0.782778
# classicrock         0.220221
# country             0.612499
# dancepop            0.258993
# deathmetal          0.489376
# electronic          0.687691
# folk                0.422663
# folkrock            0.329842
# hardrock            0.373373
# heavymetal          0.404109
# hiphop              0.904171
# house               0.324807
# indierock           0.413334
# jazz                0.709344
# metal               0.642903
# newwave             0.322439
# pop                 0.586461
# poprock             0.274333
# powermetal          0.474802
# progressiverock     0.465666
# punk                0.470425
# rb                  0.291548
# reggae              0.717467
# rock                0.483447
# ...
