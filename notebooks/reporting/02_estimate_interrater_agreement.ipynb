# %%
import pandas as pd
from helpers.interrater_agreement import print_simulated_interrater_agreement
granularities = [5, 12, 25, 32]

def read_and_print_ira(granularity):
    print("=" * 60)
    print(f"{granularity} GENRE CATEGORIES")
    print("=" * 60)
    mc = pd.read_csv(f"../../models/interrater_agreement/ira_cat{granularity}.csv")
    print_simulated_interrater_agreement(mc)


for g in granularities:
    read_and_print_ira(g)
# Out:
# ============================================================
# 5 GENRE CATEGORIES
# ============================================================
# SIMULATED INTERRATER AGREEMENT (MONTE CARLO):
# ============================================================
# MC iterations: 10
# Mean Macro F1: 0.789 ± 0.001 (stddev)
# 95% CI: [0.788, 0.790]
# ============================================================
#             mean   std  CI lower  CI upper
# genre
# hiphop     0.904 0.001     0.903     0.906
# rock       0.835 0.001     0.834     0.837
# pop        0.768 0.001     0.766     0.769
# electronic 0.728 0.002     0.725     0.730
# metal      0.713 0.003     0.710     0.716
# ============================================================
# 12 GENRE CATEGORIES
# ============================================================
# SIMULATED INTERRATER AGREEMENT (MONTE CARLO):
# ============================================================
# MC iterations: 10
# Mean Macro F1: 0.602 ± 0.001 (stddev)
# 95% CI: [0.601, 0.603]
# ============================================================
#                  mean   std  CI lower  CI upper
# genre
# hiphop          0.904 0.001     0.902     0.906
# schlager        0.796 0.003     0.792     0.801
# electronic      0.727 0.002     0.724     0.730
# metal           0.713 0.003     0.708     0.719
# jazz            0.710 0.004     0.705     0.716
# pop             0.703 0.001     0.700     0.705
# rock            0.677 0.002     0.674     0.679
# heavymetal      0.548 0.005     0.540     0.556
# indierock       0.413 0.009     0.400     0.428
# alternativerock 0.387 0.005     0.379     0.393
# hardrock        0.376 0.006     0.368     0.385
# poprock         0.272 0.005     0.266     0.281
# ============================================================
# 25 GENRE CATEGORIES
# ============================================================
# SIMULATED INTERRATER AGREEMENT (MONTE CARLO):
# ============================================================
# MC iterations: 10
# Mean Macro F1: 0.480 ± 0.002 (stddev)
# 95% CI: [0.478, 0.483]
# ============================================================
#                   mean   std  CI lower  CI upper
# genre
# hiphop           0.904 0.001     0.903     0.906
# schlager         0.796 0.003     0.792     0.801
# classical        0.783 0.007     0.773     0.792
# electronic       0.727 0.002     0.724     0.730
# jazz             0.710 0.004     0.703     0.715
# metal            0.643 0.003     0.639     0.647
# pop              0.620 0.002     0.619     0.624
# rock             0.527 0.002     0.524     0.530
# deathmetal       0.489 0.008     0.476     0.500
# powermetal       0.475 0.009     0.463     0.489
# punk             0.470 0.006     0.462     0.481
# progressiverock  0.466 0.005     0.460     0.474
# folk             0.423 0.009     0.411     0.438
# indierock        0.413 0.007     0.405     0.424
# heavymetal       0.404 0.006     0.397     0.415
# soul             0.394 0.008     0.382     0.405
# alternativerock  0.387 0.005     0.379     0.393
# hardrock         0.374 0.006     0.368     0.384
# bluesrock        0.341 0.008     0.331     0.357
# folkrock         0.331 0.013     0.317     0.352
# rb               0.292 0.010     0.276     0.304
# synthpop         0.274 0.010     0.256     0.287
# poprock          0.273 0.004     0.269     0.280
# singersongwriter 0.261 0.006     0.251     0.271
# classicrock      0.221 0.009     0.211     0.237
# ============================================================
# 32 GENRE CATEGORIES
# ============================================================
# SIMULATED INTERRATER AGREEMENT (MONTE CARLO):
# ============================================================
# MC iterations: 10
# Mean Macro F1: 0.463 ± 0.002 (stddev)
# 95% CI: [0.461, 0.466]
# ============================================================
#                   mean   std  CI lower  CI upper
# genre
# hiphop           0.904 0.001     0.902     0.905
# schlager         0.796 0.003     0.793     0.801
# classical        0.783 0.007     0.773     0.792
# reggae           0.717 0.005     0.710     0.725
# jazz             0.709 0.004     0.704     0.714
# electronic       0.688 0.001     0.686     0.690
# metal            0.643 0.002     0.639     0.647
# country          0.612 0.010     0.598     0.628
# pop              0.586 0.002     0.584     0.591
# deathmetal       0.489 0.008     0.476     0.500
# rock             0.483 0.002     0.480     0.487
# powermetal       0.475 0.009     0.463     0.490
# punk             0.470 0.007     0.462     0.481
# progressiverock  0.466 0.005     0.459     0.473
# blues            0.451 0.013     0.433     0.470
# folk             0.423 0.010     0.407     0.440
# indierock        0.413 0.007     0.405     0.427
# heavymetal       0.404 0.006     0.398     0.414
# soul             0.394 0.008     0.382     0.405
# alternativerock  0.387 0.005     0.379     0.393
# hardrock         0.373 0.006     0.367     0.384
# bluesrock        0.342 0.008     0.334     0.354
# folkrock         0.330 0.013     0.315     0.352
# house            0.325 0.006     0.317     0.335
# newwave          0.322 0.015     0.294     0.339
# rb               0.292 0.009     0.277     0.304
# poprock          0.274 0.004     0.270     0.280
# synthpop         0.274 0.010     0.256     0.287
# singersongwriter 0.260 0.005     0.250     0.266
# dancepop         0.259 0.012     0.247     0.282
# softrock         0.257 0.010     0.246     0.275
# classicrock      0.220 0.009     0.209     0.236
