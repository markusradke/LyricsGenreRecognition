# %%
import pandas as pd
from helpers.interrater_agreement import print_simulated_interrater_agreement
granularities = [5, 12, 25, 32]

def read_and_print_ira(granularity):
    print("=" * 60)
    print(f"{granularity} GENRE CATEGORIES")
    print("=" * 60)
    mc = pd.read_csv(f"../../models/interrater_agreement/ira_cat{granularity}.csv")
    print_simulated_interrater_agreement(mc)


for g in granularities:
    read_and_print_ira(g)
# Out:
# ============================================================
# 5 GENRE CATEGORIES
# ============================================================
# SIMULATED INTERRATER AGREEMENT (MONTE CARLO):
# ============================================================
# MC iterations: 10,000
# Mean Macro F1: 0.790 ± 0.001 (stddev)
# 95% CI: [0.788, 0.792]
# ============================================================
#             mean   std  CI lower  CI upper
# genre
# hiphop     0.904 0.001     0.902     0.907
# rock       0.835 0.001     0.834     0.837
# pop        0.768 0.001     0.766     0.771
# electronic 0.728 0.002     0.723     0.732
# metal      0.714 0.003     0.709     0.719
# ============================================================
# 12 GENRE CATEGORIES
# ============================================================
# SIMULATED INTERRATER AGREEMENT (MONTE CARLO):
# ============================================================
# MC iterations: 10,000
# Mean Macro F1: 0.603 ± 0.001 (stddev)
# 95% CI: [0.600, 0.605]
# ============================================================
#                  mean   std  CI lower  CI upper
# genre
# hiphop          0.904 0.001     0.902     0.907
# schlager        0.796 0.004     0.788     0.803
# electronic      0.728 0.002     0.723     0.732
# metal           0.714 0.003     0.709     0.719
# jazz            0.711 0.004     0.703     0.720
# pop             0.704 0.002     0.701     0.707
# rock            0.678 0.001     0.675     0.680
# heavymetal      0.550 0.005     0.541     0.559
# indierock       0.412 0.007     0.399     0.426
# alternativerock 0.386 0.005     0.376     0.396
# hardrock        0.375 0.006     0.362     0.388
# poprock         0.273 0.006     0.262     0.285
# ============================================================
# 25 GENRE CATEGORIES
# ============================================================
# SIMULATED INTERRATER AGREEMENT (MONTE CARLO):
# ============================================================
# MC iterations: 10,000
# Mean Macro F1: 0.480 ± 0.002 (stddev)
# 95% CI: [0.477, 0.483]
# ============================================================
#                   mean   std  CI lower  CI upper
# genre
# hiphop           0.904 0.001     0.902     0.907
# schlager         0.796 0.004     0.788     0.803
# classical        0.782 0.005     0.771     0.792
# electronic       0.728 0.002     0.723     0.732
# jazz             0.711 0.004     0.703     0.720
# metal            0.643 0.003     0.637     0.649
# pop              0.622 0.002     0.618     0.626
# rock             0.527 0.002     0.523     0.531
# deathmetal       0.491 0.010     0.471     0.511
# powermetal       0.478 0.010     0.458     0.498
# punk             0.474 0.007     0.460     0.488
# progressiverock  0.465 0.008     0.449     0.481
# folk             0.420 0.009     0.403     0.438
# indierock        0.412 0.007     0.398     0.425
# heavymetal       0.406 0.006     0.394     0.418
# soul             0.395 0.008     0.379     0.410
# alternativerock  0.386 0.005     0.376     0.396
# hardrock         0.375 0.006     0.362     0.387
# bluesrock        0.340 0.011     0.319     0.360
# folkrock         0.332 0.010     0.313     0.351
# rb               0.292 0.010     0.273     0.312
# synthpop         0.279 0.009     0.261     0.297
# poprock          0.273 0.006     0.262     0.285
# singersongwriter 0.260 0.010     0.240     0.281
# classicrock      0.216 0.009     0.198     0.235
# ============================================================
# 32 GENRE CATEGORIES
# ============================================================
# SIMULATED INTERRATER AGREEMENT (MONTE CARLO):
# ============================================================
# MC iterations: 10,000
# Mean Macro F1: 0.464 ± 0.001 (stddev)
# 95% CI: [0.461, 0.467]
# ============================================================
#                   mean   std  CI lower  CI upper
# genre
# hiphop           0.904 0.001     0.902     0.907
# schlager         0.796 0.004     0.788     0.803
# classical        0.782 0.005     0.771     0.792
# reggae           0.719 0.008     0.704     0.734
# jazz             0.711 0.004     0.703     0.720
# electronic       0.688 0.002     0.683     0.692
# metal            0.643 0.003     0.637     0.649
# country          0.612 0.009     0.594     0.629
# pop              0.588 0.002     0.584     0.592
# deathmetal       0.491 0.010     0.471     0.511
# rock             0.484 0.002     0.480     0.488
# powermetal       0.478 0.010     0.458     0.498
# punk             0.474 0.007     0.460     0.488
# progressiverock  0.465 0.008     0.449     0.481
# blues            0.449 0.010     0.430     0.468
# folk             0.420 0.009     0.403     0.438
# indierock        0.412 0.007     0.398     0.425
# heavymetal       0.406 0.006     0.394     0.418
# soul             0.395 0.008     0.379     0.410
# alternativerock  0.386 0.005     0.376     0.396
# hardrock         0.375 0.006     0.362     0.387
# bluesrock        0.340 0.011     0.319     0.361
# folkrock         0.332 0.009     0.313     0.351
# house            0.324 0.011     0.302     0.347
# newwave          0.319 0.011     0.297     0.341
# rb               0.292 0.010     0.273     0.312
# synthpop         0.279 0.009     0.261     0.297
# poprock          0.273 0.006     0.262     0.285
# singersongwriter 0.260 0.010     0.240     0.281
# dancepop         0.260 0.011     0.239     0.281
# softrock         0.260 0.011     0.238     0.282
# classicrock      0.216 0.009     0.198     0.234
