# %%
import pandas as pd
from helpers.interrater_agreement import print_simulated_interrater_agreement
granularities = [5, 12, 25, 32]

def read_and_print_ira(granularity):
    print("=" * 60)
    print(f"{granularity} GENRE CATEGORIES")
    print("=" * 60)
    mc = pd.read_csv(f"../../models/interrater_agreement/ira_cat{granularity}.csv")
    print_simulated_interrater_agreement(mc)

print("ESTIMATE INTERRATER AGREEMENT FOR ENGLISH CORPUS...")
for g in granularities:
    read_and_print_ira(g)
# Out:
# ESTIMATE INTERRATER AGREEMENT FOR ENGLISH CORPUS...
# ...
# 5 GENRE CATEGORIES
# ...
# SIMULATED INTERRATER AGREEMENT (MONTE CARLO):
# ...
# MC iterations: 10,000
# Mean Macro F1: 0.754 ± 0.001 (stddev)
# 95% CI: [0.751, 0.756]
# ...
#             mean   std  CI lower  CI upper
# genre
# hiphop     0.843 0.003     0.838     0.848
# rock       0.842 0.001     0.840     0.844
# metal      0.707 0.003     0.701     0.713
# pop        0.705 0.002     0.701     0.709
# electronic 0.672 0.003     0.666     0.678
# ...
# 12 GENRE CATEGORIES
# ...
# SIMULATED INTERRATER AGREEMENT (MONTE CARLO):
# ...
# MC iterations: 10,000
# Mean Macro F1: 0.561 ± 0.002 (stddev)
# 95% CI: [0.557, 0.564]
# ...
#                  mean   std  CI lower  CI upper
# genre
# hiphop          0.843 0.003     0.838     0.848
# metal           0.707 0.003     0.701     0.713
# pop             0.681 0.002     0.677     0.685
# electronic      0.672 0.003     0.666     0.678
# rock            0.671 0.002     0.668     0.675
# ...
